# %%
bsc_capacity(x) = 1+(x*log(x,2)+(1-x)*log(1-x,2))

# %%
plot(bsc_capacity(x), (x,0,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
# transmist 3 bits over a BSC with p=0.1

# 1/3 = number of message bits/nnmber of transmitted bits

# %%
plot(x*(1-x)^2-(1-1/625)/12, (x, 0, 1))
# Out:
# Graphics object consisting of 1 graphics primitive
